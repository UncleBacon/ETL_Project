# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file = "../Resources/economic.csv"
economic_df = pd.read_csv(csv_file)
economic_df.head()
# Out:
#   Country Name Country Code                            Series Name  \
# 0  Afghanistan          AFG                  GDP growth (annual %)
# 1  Afghanistan          AFG     GDP per capita (constant 2005 US$)
# 2  Afghanistan          AFG  Inflation, consumer prices (annual %)
# 3      Albania          ALB                  GDP growth (annual %)
# 4      Albania          ALB     GDP per capita (constant 2005 US$)
#
#          Series Code     2000 [YR2000]     2005 [YR2005]     2010 [YR2010]  \
# 0  NY.GDP.MKTP.KD.ZG                ..  11.1752702416587  8.43329048161792
# 1     NY.GDP.PCAP.KD                ..  389.416357791097  553.300289383064
# 2     FP.CPI.TOTL.ZG                ..       12.68626872       0.892536936
# 3  NY.GDP.MKTP.KD.ZG  6.66662049881369  5.72081994678555  3.71005779297435
# 4     NY.GDP.PCAP.KD   2337.9423863713  3189.39511117692  4094.35883191918
#
#       2015 [YR2015]     2016 [YR2016]
# 0  1.31004040372002  2.36671191565063
# 1   620.05652498092  617.889972323552
# 2      -1.533846583       2.169452176
# 3   2.2187520539882  3.35215921082479
# 4  4524.64443153606  4683.80021257139

# %% [markdown]
# ### Create new data with select columns

# %%
new_economic_df = economic_df[['Country Name', 'Series Name', '2000 [YR2000]', '2005 [YR2005]', '2010 [YR2010]', '2015 [YR2015]', '2016 [YR2016]']].copy()
new_economic_df.head()
# Out:
#   Country Name                            Series Name     2000 [YR2000]  \
# 0  Afghanistan                  GDP growth (annual %)                ..
# 1  Afghanistan     GDP per capita (constant 2005 US$)                ..
# 2  Afghanistan  Inflation, consumer prices (annual %)                ..
# 3      Albania                  GDP growth (annual %)  6.66662049881369
# 4      Albania     GDP per capita (constant 2005 US$)   2337.9423863713
#
#       2005 [YR2005]     2010 [YR2010]     2015 [YR2015]     2016 [YR2016]
# 0  11.1752702416587  8.43329048161792  1.31004040372002  2.36671191565063
# 1  389.416357791097  553.300289383064   620.05652498092  617.889972323552
# 2       12.68626872       0.892536936      -1.533846583       2.169452176
# 3  5.72081994678555  3.71005779297435   2.2187520539882  3.35215921082479
# 4  3189.39511117692  4094.35883191918  4524.64443153606  4683.80021257139

# %%
new_economic_df = new_economic_df.rename(columns={"2000 [YR2000]": 2000, "2005 [YR2005]": 2005, "2010 [YR2010]": 2010, 
                                                  "2015 [YR2015]": 2015, "2016 [YR2016]": 2016})
new_economic_df
# Out:
#                  Country Name                            Series Name  \
# 0                 Afghanistan                  GDP growth (annual %)
# 1                 Afghanistan     GDP per capita (constant 2005 US$)
# 2                 Afghanistan  Inflation, consumer prices (annual %)
# 3                     Albania                  GDP growth (annual %)
# 4                     Albania     GDP per capita (constant 2005 US$)
# ..                        ...                                    ...
# 726                       NaN                                    NaN
# 727                       NaN                                    NaN
# 728                       NaN                                    NaN
# 729  Data from database: Jobs                                    NaN
# 730  Last Updated: 10/28/2019                                    NaN
#
#                  2000              2005              2010              2015  \
# 0                  ..  11.1752702416587  8.43329048161792  1.31004040372002
# 1                  ..  389.416357791097  553.300289383064   620.05652498092
# 2                  ..       12.68626872       0.892536936      -1.533846583
# 3    6.66662049881369  5.72081994678555  3.71005779297435   2.2187520539882
# 4     2337.9423863713  3189.39511117692  4094.35883191918  4524.64443153606
# ..                ...               ...               ...               ...
# 726               NaN               NaN               NaN               NaN
# 727               NaN               NaN               NaN               NaN
# 728               NaN               NaN               NaN               NaN
# 729               NaN               NaN               NaN               NaN
# 730               NaN               NaN               NaN               NaN
#
#                  2016
# 0    2.36671191565063
# 1    617.889972323552
# 2         2.169452176
# 3    3.35215921082479
# 4    4683.80021257139
# ..                ...
# 726               NaN
# 727               NaN
# 728               NaN
# 729               NaN
# 730               NaN
#
# [731 rows x 7 columns]

# %%
new_economic_df = pd.melt(new_economic_df, id_vars=['Country Name', "Series Name"], value_vars=[2000, 2005, 2010, 2015,2016])
new_economic_df
# Out:
#                   Country Name                            Series Name  \
# 0                  Afghanistan                  GDP growth (annual %)
# 1                  Afghanistan     GDP per capita (constant 2005 US$)
# 2                  Afghanistan  Inflation, consumer prices (annual %)
# 3                      Albania                  GDP growth (annual %)
# 4                      Albania     GDP per capita (constant 2005 US$)
# ...                        ...                                    ...
# 3650                       NaN                                    NaN
# 3651                       NaN                                    NaN
# 3652                       NaN                                    NaN
# 3653  Data from database: Jobs                                    NaN
# 3654  Last Updated: 10/28/2019                                    NaN
#
#      variable             value
# 0        2000                ..
# 1        2000                ..
# 2        2000                ..
# 3        2000  6.66662049881369
# 4        2000   2337.9423863713
# ...       ...               ...
# 3650     2016               NaN
# 3651     2016               NaN
# 3652     2016               NaN
# 3653     2016               NaN
# 3654     2016               NaN
#
# [3655 rows x 4 columns]

# %%
new_economic_df.dtypes
# Out:
# Country Name    object
# Series Name     object
# variable        object
# value           object
# dtype: object

# %%
new_economic_df = new_economic_df.dropna()
new_economic_df
# Out:
#      Country Name                            Series Name variable  \
# 0     Afghanistan                  GDP growth (annual %)     2000
# 1     Afghanistan     GDP per capita (constant 2005 US$)     2000
# 2     Afghanistan  Inflation, consumer prices (annual %)     2000
# 3         Albania                  GDP growth (annual %)     2000
# 4         Albania     GDP per capita (constant 2005 US$)     2000
# ...           ...                                    ...      ...
# 3645       Zambia     GDP per capita (constant 2005 US$)     2016
# 3646       Zambia  Inflation, consumer prices (annual %)     2016
# 3647     Zimbabwe                  GDP growth (annual %)     2016
# 3648     Zimbabwe     GDP per capita (constant 2005 US$)     2016
# 3649     Zimbabwe  Inflation, consumer prices (annual %)     2016
#
#                   value
# 0                    ..
# 1                    ..
# 2                    ..
# 3      6.66662049881369
# 4       2337.9423863713
# ...                 ...
# 3645   1629.59030492169
# 3646        17.86996005
# 3647  0.615713754356918
# 3648   917.563719684227
# 3649        -1.55978908
#
# [3630 rows x 4 columns]

# %%
new_economic_df = new_economic_df.replace("..", 0)
new_economic_df
# Out:
#      Country Name                            Series Name  variable  \
# 0     Afghanistan                  GDP growth (annual %)      2000
# 1     Afghanistan     GDP per capita (constant 2005 US$)      2000
# 2     Afghanistan  Inflation, consumer prices (annual %)      2000
# 3         Albania                  GDP growth (annual %)      2000
# 4         Albania     GDP per capita (constant 2005 US$)      2000
# ...           ...                                    ...       ...
# 3645       Zambia     GDP per capita (constant 2005 US$)      2016
# 3646       Zambia  Inflation, consumer prices (annual %)      2016
# 3647     Zimbabwe                  GDP growth (annual %)      2016
# 3648     Zimbabwe     GDP per capita (constant 2005 US$)      2016
# 3649     Zimbabwe  Inflation, consumer prices (annual %)      2016
#
#                   value
# 0                     0
# 1                     0
# 2                     0
# 3      6.66662049881369
# 4       2337.9423863713
# ...                 ...
# 3645   1629.59030492169
# 3646        17.86996005
# 3647  0.615713754356918
# 3648   917.563719684227
# 3649        -1.55978908
#
# [3630 rows x 4 columns]

# %%
new_economic_df['value'].astype(float)
new_economic_df.dtypes
# Out:
# Country Name    object
# Series Name     object
# variable         int64
# value           object
# dtype: object

# %%
new_economic_df = new_economic_df.dropna()
# Out:
#      Country Name                            Series Name variable  \
# 0     Afghanistan                  GDP growth (annual %)     2000
# 1     Afghanistan     GDP per capita (constant 2005 US$)     2000
# 2     Afghanistan  Inflation, consumer prices (annual %)     2000
# 3         Albania                  GDP growth (annual %)     2000
# 4         Albania     GDP per capita (constant 2005 US$)     2000
# ...           ...                                    ...      ...
# 3645       Zambia     GDP per capita (constant 2005 US$)     2016
# 3646       Zambia  Inflation, consumer prices (annual %)     2016
# 3647     Zimbabwe                  GDP growth (annual %)     2016
# 3648     Zimbabwe     GDP per capita (constant 2005 US$)     2016
# 3649     Zimbabwe  Inflation, consumer prices (annual %)     2016
#
#                   value
# 0                    ..
# 1                    ..
# 2                    ..
# 3      6.66662049881369
# 4       2337.9423863713
# ...                 ...
# 3645   1629.59030492169
# 3646        17.86996005
# 3647  0.615713754356918
# 3648   917.563719684227
# 3649        -1.55978908
#
# [3630 rows x 4 columns]

# %%
pd.pivot_table(new_economic_df, values=['Series Name'], index=['Country Name', 'variable'], columns=['value'])
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-14-34924ae20181> in <module>
# ----> 1 pd.pivot_table(new_economic_df, values=['Series Name'], index=['Country Name', 'variable'], columns=['value'])
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      94
#      95     grouped = data.groupby(keys, observed=observed)
# ---> 96     agged = grouped.agg(aggfunc)
#      97     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#      98         agged = agged.dropna(how="all")
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#    1453     @Appender(_shared_docs["aggregate"])
#    1454     def aggregate(self, arg=None, *args, **kwargs):
# -> 1455         return super().aggregate(arg, *args, **kwargs)
#    1456
#    1457     agg = aggregate
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, *args, **kwargs)
#     227         func = _maybe_mangle_lambdas(func)
#     228
# --> 229         result, how = self._aggregate(func, _level=_level, *args, **kwargs)
#     230         if how is None:
#     231             return result
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     354
#     355         if isinstance(arg, str):
# --> 356             return self._try_aggregate_string_function(arg, *args, **kwargs), None
#     357
#     358         if isinstance(arg, dict):
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/base.py in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     303         if f is not None:
#     304             if callable(f):
# --> 305                 return f(*args, **kwargs)
#     306
#     307             # people may try to aggregate on a non-callable attribute
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1203         try:
#    1204             return self._cython_agg_general(
# -> 1205                 "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1206             )
#    1207         except GroupByError:
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     126     def _cython_agg_general(self, how, alt=None, numeric_only=True, min_count=-1):
#     127         new_items, new_blocks = self._cython_agg_blocks(
# --> 128             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#     129         )
#     130         return self._wrap_agged_blocks(new_items, new_blocks)
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#     186
#     187         if len(new_blocks) == 0:
# --> 188             raise DataError("No numeric types to aggregate")
#     189
#     190         # reset the locs in the blocks to correspond to our
#
# DataError: No numeric types to aggregate

# %%
pd.pivot_table(new_economic_df, values=['Series Name'], index=['Country Name', 'variable'], columns=['value'])
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-34-34924ae20181> in <module>
# ----> 1 pd.pivot_table(new_economic_df, values=['Series Name'], index=['Country Name', 'variable'], columns=['value'])
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      94
#      95     grouped = data.groupby(keys, observed=observed)
# ---> 96     agged = grouped.agg(aggfunc)
#      97     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#      98         agged = agged.dropna(how="all")
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#    1453     @Appender(_shared_docs["aggregate"])
#    1454     def aggregate(self, arg=None, *args, **kwargs):
# -> 1455         return super().aggregate(arg, *args, **kwargs)
#    1456
#    1457     agg = aggregate
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, *args, **kwargs)
#     227         func = _maybe_mangle_lambdas(func)
#     228
# --> 229         result, how = self._aggregate(func, _level=_level, *args, **kwargs)
#     230         if how is None:
#     231             return result
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     354
#     355         if isinstance(arg, str):
# --> 356             return self._try_aggregate_string_function(arg, *args, **kwargs), None
#     357
#     358         if isinstance(arg, dict):
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/base.py in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     303         if f is not None:
#     304             if callable(f):
# --> 305                 return f(*args, **kwargs)
#     306
#     307             # people may try to aggregate on a non-callable attribute
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1203         try:
#    1204             return self._cython_agg_general(
# -> 1205                 "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1206             )
#    1207         except GroupByError:
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     126     def _cython_agg_general(self, how, alt=None, numeric_only=True, min_count=-1):
#     127         new_items, new_blocks = self._cython_agg_blocks(
# --> 128             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#     129         )
#     130         return self._wrap_agged_blocks(new_items, new_blocks)
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#     186
#     187         if len(new_blocks) == 0:
# --> 188             raise DataError("No numeric types to aggregate")
#     189
#     190         # reset the locs in the blocks to correspond to our
#
# DataError: No numeric types to aggregate

# %%
new_economic_df['value'].astype(str).astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-7e1d9cf64722> in <module>
# ----> 1 new_economic_df['value'].astype(str).astype(float)
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     557
#     558     def astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
# --> 559         return self._astype(dtype, copy=copy, errors=errors, values=values, **kwargs)
#     560
#     561     def _astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     641                     # _astype_nansafe works fine with 1-d only
#     642                     vals1d = values.ravel()
# --> 643                     values = astype_nansafe(vals1d, dtype, copy=True, **kwargs)
#     644
#     645                 # TODO(extension)
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     727     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     728         # Explicit copy, or required since NumPy can't view from / to object.
# --> 729         return arr.astype(dtype, copy=True)
#     730
#     731     return arr.view(dtype)
#
# ValueError: could not convert string to float: '..'

# %%
pd.pivot_table(new_economic_df, values=['Series Name'], index=['Country Name', 'variable'], columns=['value'])
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-14-34924ae20181> in <module>
# ----> 1 pd.pivot_table(new_economic_df, values=['Series Name'], index=['Country Name', 'variable'], columns=['value'])
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      94
#      95     grouped = data.groupby(keys, observed=observed)
# ---> 96     agged = grouped.agg(aggfunc)
#      97     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#      98         agged = agged.dropna(how="all")
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#    1453     @Appender(_shared_docs["aggregate"])
#    1454     def aggregate(self, arg=None, *args, **kwargs):
# -> 1455         return super().aggregate(arg, *args, **kwargs)
#    1456
#    1457     agg = aggregate
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, *args, **kwargs)
#     227         func = _maybe_mangle_lambdas(func)
#     228
# --> 229         result, how = self._aggregate(func, _level=_level, *args, **kwargs)
#     230         if how is None:
#     231             return result
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     354
#     355         if isinstance(arg, str):
# --> 356             return self._try_aggregate_string_function(arg, *args, **kwargs), None
#     357
#     358         if isinstance(arg, dict):
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/base.py in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     303         if f is not None:
#     304             if callable(f):
# --> 305                 return f(*args, **kwargs)
#     306
#     307             # people may try to aggregate on a non-callable attribute
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1203         try:
#    1204             return self._cython_agg_general(
# -> 1205                 "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1206             )
#    1207         except GroupByError:
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     126     def _cython_agg_general(self, how, alt=None, numeric_only=True, min_count=-1):
#     127         new_items, new_blocks = self._cython_agg_blocks(
# --> 128             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#     129         )
#     130         return self._wrap_agged_blocks(new_items, new_blocks)
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#     186
#     187         if len(new_blocks) == 0:
# --> 188             raise DataError("No numeric types to aggregate")
#     189
#     190         # reset the locs in the blocks to correspond to our
#
# DataError: No numeric types to aggregate

# %%
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-10-d231604f82fa> in <module>
# ----> 1 pd.pivot_table(new_economic_df, values=['Series Name'], index=['Country Name', 'variable'], columns=['value'])
#       2
#       3
#       4
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      94
#      95     grouped = data.groupby(keys, observed=observed)
# ---> 96     agged = grouped.agg(aggfunc)
#      97     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#      98         agged = agged.dropna(how="all")
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, arg, *args, **kwargs)
#    1453     @Appender(_shared_docs["aggregate"])
#    1454     def aggregate(self, arg=None, *args, **kwargs):
# -> 1455         return super().aggregate(arg, *args, **kwargs)
#    1456
#    1457     agg = aggregate
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, *args, **kwargs)
#     227         func = _maybe_mangle_lambdas(func)
#     228
# --> 229         result, how = self._aggregate(func, _level=_level, *args, **kwargs)
#     230         if how is None:
#     231             return result
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     354
#     355         if isinstance(arg, str):
# --> 356             return self._try_aggregate_string_function(arg, *args, **kwargs), None
#     357
#     358         if isinstance(arg, dict):
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/base.py in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     303         if f is not None:
#     304             if callable(f):
# --> 305                 return f(*args, **kwargs)
#     306
#     307             # people may try to aggregate on a non-callable attribute
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1203         try:
#    1204             return self._cython_agg_general(
# -> 1205                 "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1206             )
#    1207         except GroupByError:
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     126     def _cython_agg_general(self, how, alt=None, numeric_only=True, min_count=-1):
#     127         new_items, new_blocks = self._cython_agg_blocks(
# --> 128             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#     129         )
#     130         return self._wrap_agged_blocks(new_items, new_blocks)
#
# ~/anaconda3/envs/python37/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#     186
#     187         if len(new_blocks) == 0:
# --> 188             raise DataError("No numeric types to aggregate")
#     189
#     190         # reset the locs in the blocks to correspond to our
#
# DataError: No numeric types to aggregate

# %% [markdown]
# ### Store JSON data into a DataFrame

# %%
json_file = "../Resources/customer_location.json"
customer_location_df = pd.read_json(json_file)
customer_location_df.head()
# Out:
#    id                address  longitude  latitude  us_state
# 0   1  043 Mockingbird Place   -86.5186   39.1682   Indiana
# 1   2       4 Prentice Point   -85.0707   41.0938   Indiana
# 2   3      46 Derek Junction   -96.7776   32.7673     Texas
# 3   4  11966 Old Shore Place   -94.3567   39.0350  Missouri
# 4   5     5 Evergreen Circle   -73.9772   40.7808  New York

# %% [markdown]
# ### Clean DataFrame

# %%
new_customer_location_df = customer_location_df[["id", "address", "us_state"]].copy()
new_customer_location_df.head()
# Out:
#    id                address  us_state
# 0   1  043 Mockingbird Place   Indiana
# 1   2       4 Prentice Point   Indiana
# 2   3      46 Derek Junction     Texas
# 3   4  11966 Old Shore Place  Missouri
# 4   5     5 Evergreen Circle  New York

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = "postgres:postgres@localhost:5432/client_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# ['customer_name', 'customer_location']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
new_customer_data_df.to_sql(name='customer_name', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Use pandas to load json converted DataFrame into database

# %%
new_customer_location_df.to_sql(name='customer_location', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the customer_name table
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from customer_name', con=engine).head()
# Out:
#    id first_name last_name
# 0   1    Benetta   Cancott
# 1   2     Lilyan    Cherry
# 2   3    Ezekiel   Benasik
# 3   4    Kennedy     Atlay
# 4   5    Sanford    Salmen

# %% [markdown]
# ### Confirm data has been added by querying the customer_location table

# %%
pd.read_sql_query('select * from customer_location', con=engine).head()
# Out:
#    id                address  us_state
# 0   1  043 Mockingbird Place   Indiana
# 1   2       4 Prentice Point   Indiana
# 2   3      46 Derek Junction     Texas
# 3   4  11966 Old Shore Place  Missouri
# 4   5     5 Evergreen Circle  New York
