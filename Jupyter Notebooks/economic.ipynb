# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
from config import (ServerName, UserName, Password, port, DataBase)

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file = "../Resources/economic.csv"
economic_df = pd.read_csv(csv_file)
economic_df.head()
# Out:
#   Country Name Country Code                            Series Name  \
# 0  Afghanistan          AFG                  GDP growth (annual %)
# 1  Afghanistan          AFG     GDP per capita (constant 2005 US$)
# 2  Afghanistan          AFG  Inflation, consumer prices (annual %)
# 3      Albania          ALB                  GDP growth (annual %)
# 4      Albania          ALB     GDP per capita (constant 2005 US$)
#
#          Series Code     2000 [YR2000]     2005 [YR2005]     2010 [YR2010]  \
# 0  NY.GDP.MKTP.KD.ZG                ..  11.1752702416587  8.43329048161792
# 1     NY.GDP.PCAP.KD                ..  389.416357791097  553.300289383064
# 2     FP.CPI.TOTL.ZG                ..       12.68626872       0.892536936
# 3  NY.GDP.MKTP.KD.ZG  6.66662049881369  5.72081994678555  3.71005779297435
# 4     NY.GDP.PCAP.KD   2337.9423863713  3189.39511117692  4094.35883191918
#
#       2015 [YR2015]     2016 [YR2016]
# 0  1.31004040372002  2.36671191565063
# 1   620.05652498092  617.889972323552
# 2      -1.533846583       2.169452176
# 3   2.2187520539882  3.35215921082479
# 4  4524.64443153606  4683.80021257139

# %% [markdown]
# ### Create new data with select columns

# %%
new_economic_df = economic_df[['Country Name', 'Series Name', '2000 [YR2000]', '2005 [YR2005]', '2010 [YR2010]', '2015 [YR2015]', '2016 [YR2016]']].copy()
new_economic_df.head()
# Out:
#   Country Name                            Series Name     2000 [YR2000]  \
# 0  Afghanistan                  GDP growth (annual %)                ..
# 1  Afghanistan     GDP per capita (constant 2005 US$)                ..
# 2  Afghanistan  Inflation, consumer prices (annual %)                ..
# 3      Albania                  GDP growth (annual %)  6.66662049881369
# 4      Albania     GDP per capita (constant 2005 US$)   2337.9423863713
#
#       2005 [YR2005]     2010 [YR2010]     2015 [YR2015]     2016 [YR2016]
# 0  11.1752702416587  8.43329048161792  1.31004040372002  2.36671191565063
# 1  389.416357791097  553.300289383064   620.05652498092  617.889972323552
# 2       12.68626872       0.892536936      -1.533846583       2.169452176
# 3  5.72081994678555  3.71005779297435   2.2187520539882  3.35215921082479
# 4  3189.39511117692  4094.35883191918  4524.64443153606  4683.80021257139

# %% [markdown]
# ### Rename Columns

# %%
new_economic_df = new_economic_df.rename(columns={"Country Name" : "Country", "2000 [YR2000]": 2000, "2005 [YR2005]": 2005, "2010 [YR2010]": 2010, 
                                                  "2015 [YR2015]": 2015, "2016 [YR2016]": 2016})
new_economic_df
# Out:
#                       Country                            Series Name  \
# 0                 Afghanistan                  GDP growth (annual %)
# 1                 Afghanistan     GDP per capita (constant 2005 US$)
# 2                 Afghanistan  Inflation, consumer prices (annual %)
# 3                     Albania                  GDP growth (annual %)
# 4                     Albania     GDP per capita (constant 2005 US$)
# ..                        ...                                    ...
# 726                       NaN                                    NaN
# 727                       NaN                                    NaN
# 728                       NaN                                    NaN
# 729  Data from database: Jobs                                    NaN
# 730  Last Updated: 10/28/2019                                    NaN
#
#                  2000              2005              2010              2015  \
# 0                  ..  11.1752702416587  8.43329048161792  1.31004040372002
# 1                  ..  389.416357791097  553.300289383064   620.05652498092
# 2                  ..       12.68626872       0.892536936      -1.533846583
# 3    6.66662049881369  5.72081994678555  3.71005779297435   2.2187520539882
# 4     2337.9423863713  3189.39511117692  4094.35883191918  4524.64443153606
# ..                ...               ...               ...               ...
# 726               NaN               NaN               NaN               NaN
# 727               NaN               NaN               NaN               NaN
# 728               NaN               NaN               NaN               NaN
# 729               NaN               NaN               NaN               NaN
# 730               NaN               NaN               NaN               NaN
#
#                  2016
# 0    2.36671191565063
# 1    617.889972323552
# 2         2.169452176
# 3    3.35215921082479
# 4    4683.80021257139
# ..                ...
# 726               NaN
# 727               NaN
# 728               NaN
# 729               NaN
# 730               NaN
#
# [731 rows x 7 columns]

# %% [markdown]
# ## Melt Years

# %%
new_economic_df = pd.melt(new_economic_df, id_vars=['Country', "Series Name"], value_vars=[2000, 2005, 2010, 2015,2016])
new_economic_df
# Out:
#                        Country                            Series Name  \
# 0                  Afghanistan                  GDP growth (annual %)
# 1                  Afghanistan     GDP per capita (constant 2005 US$)
# 2                  Afghanistan  Inflation, consumer prices (annual %)
# 3                      Albania                  GDP growth (annual %)
# 4                      Albania     GDP per capita (constant 2005 US$)
# ...                        ...                                    ...
# 3650                       NaN                                    NaN
# 3651                       NaN                                    NaN
# 3652                       NaN                                    NaN
# 3653  Data from database: Jobs                                    NaN
# 3654  Last Updated: 10/28/2019                                    NaN
#
#      variable             value
# 0        2000                ..
# 1        2000                ..
# 2        2000                ..
# 3        2000  6.66662049881369
# 4        2000   2337.9423863713
# ...       ...               ...
# 3650     2016               NaN
# 3651     2016               NaN
# 3652     2016               NaN
# 3653     2016               NaN
# 3654     2016               NaN
#
# [3655 rows x 4 columns]

# %% [markdown]
# ## Rename Year Column

# %%
new_economic_df = new_economic_df.rename(columns={"Country Name": "Country", "variable": "Year"})
new_economic_df
# Out:
#                        Country                            Series Name  Year  \
# 0                  Afghanistan                  GDP growth (annual %)  2000
# 1                  Afghanistan     GDP per capita (constant 2005 US$)  2000
# 2                  Afghanistan  Inflation, consumer prices (annual %)  2000
# 3                      Albania                  GDP growth (annual %)  2000
# 4                      Albania     GDP per capita (constant 2005 US$)  2000
# ...                        ...                                    ...   ...
# 3650                       NaN                                    NaN  2016
# 3651                       NaN                                    NaN  2016
# 3652                       NaN                                    NaN  2016
# 3653  Data from database: Jobs                                    NaN  2016
# 3654  Last Updated: 10/28/2019                                    NaN  2016
#
#                  value
# 0                   ..
# 1                   ..
# 2                   ..
# 3     6.66662049881369
# 4      2337.9423863713
# ...                ...
# 3650               NaN
# 3651               NaN
# 3652               NaN
# 3653               NaN
# 3654               NaN
#
# [3655 rows x 4 columns]

# %% [markdown]
# ### Replace ".." with Zero (0) and drop NA

# %%
new_economic_df = new_economic_df.replace("..", 0)
new_economic_df
# Out:
#                        Country                            Series Name  Year  \
# 0                  Afghanistan                  GDP growth (annual %)  2000
# 1                  Afghanistan     GDP per capita (constant 2005 US$)  2000
# 2                  Afghanistan  Inflation, consumer prices (annual %)  2000
# 3                      Albania                  GDP growth (annual %)  2000
# 4                      Albania     GDP per capita (constant 2005 US$)  2000
# ...                        ...                                    ...   ...
# 3650                       NaN                                    NaN  2016
# 3651                       NaN                                    NaN  2016
# 3652                       NaN                                    NaN  2016
# 3653  Data from database: Jobs                                    NaN  2016
# 3654  Last Updated: 10/28/2019                                    NaN  2016
#
#                  value
# 0                    0
# 1                    0
# 2                    0
# 3     6.66662049881369
# 4      2337.9423863713
# ...                ...
# 3650               NaN
# 3651               NaN
# 3652               NaN
# 3653               NaN
# 3654               NaN
#
# [3655 rows x 4 columns]

# %% [markdown]
# ### Reorganize Rows and Columns with Pivot Tables

# %%
new_economic_df = pd.pivot_table(new_economic_df, values='value', index=['Country', 'Year'],
                     columns=['Series Name'], aggfunc=np.sum)
new_economic_df
# Out:
# Series Name      GDP growth (annual %) GDP per capita (constant 2005 US$)  \
# Country     Year
# Afghanistan 2000                     0                                  0
#             2005      11.1752702416587                   389.416357791097
#             2010      8.43329048161792                   553.300289383064
#             2015      1.31004040372002                    620.05652498092
#             2016      2.36671191565063                   617.889972323552
# ...                                ...                                ...
# Zimbabwe    2000     -3.05918962553469                    1261.1630883256
#             2005      -5.7110838330468                   811.562954376746
#             2010      12.5810269716888                     719.9795162923
#             2015      1.68959459207842                    933.50326674854
#             2016     0.615713754356918                   917.563719684227
#
# Series Name      Inflation, consumer prices (annual %)
# Country     Year
# Afghanistan 2000                                     0
#             2005                           12.68626872
#             2010                           0.892536936
#             2015                          -1.533846583
#             2016                           2.169452176
# ...                                                ...
# Zimbabwe    2000                           55.86645207
#             2005                           302.1169963
#             2010                           3.034478884
#             2015                          -2.398709959
#             2016                           -1.55978908
#
# [1210 rows x 3 columns]

# %% [markdown]
# ### Rename Remaining Columns

# %%
new_economic_df = new_economic_df.rename(columns={"GDP growth (annual %)": "GDP growth", 
                                                  "GDP per capita (constant 2005 US$)": "GDP per capita",
                                                  "Inflation, consumer prices (annual %)":"Inflation"})
new_economic_df
# Out:
# Series Name              GDP growth    GDP per capita     Inflation
# Country     Year
# Afghanistan 2000                  0                 0             0
#             2005   11.1752702416587  389.416357791097   12.68626872
